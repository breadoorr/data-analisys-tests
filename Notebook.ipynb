# %%
import os
from main import PlotDrawer
from IPython.display import Image, display

# Instantiate the PlotDrawer with the JSON file
plot_drawer = PlotDrawer('deviation.json')

# Draw plots and get their paths
plot_paths = plot_drawer.draw_plots()

# Display the plots
for plot_path in plot_paths:
    display(Image(filename=plot_path))
# Out:
# JSON data loaded successfully.
# Index(['name', 'gt_corners', 'rb_corners', 'mean', 'max', 'min', 'floor_mean',
#        'floor_max', 'floor_min', 'ceiling_mean', 'ceiling_max', 'ceiling_min'],
#       dtype='object')
# DataFrame created successfully.
